# %%
# remover duplicados

# corrigir tipos

# corrigir datas

# padronizar municípios

# padronizar estados

# padronizar nomes

# tratar valores nulos

# remover espaços

# padronizar letras maiúsculas
